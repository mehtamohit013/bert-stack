# %%
# !pip install unidecode
# !pip install word2number
# !pip install gensim

# %%
! sudo apt install openjdk-8-jdk
! sudo update-alternatives --set java /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/java
! pip install language-check
! pip install pycontractions

# %%
from bs4 import BeautifulSoup
import spacy
import unidecode
from word2number import w2n
from pycontractions import Contractions
import gensim.downloader as api
import en_core_web_sm
import re

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
nlp = en_core_web_sm.load()

# Choose model accordingly for contractions function
model = api.load("glove-twitter-25")
# model = api.load("glove-twitter-100")
# model = api.load("word2vec-google-news-300")

cont = Contractions(kv_model=model)
cont.load_models()

# exclude words from spacy stopwords list
deselect_stop_words = ['no', 'not']
for w in deselect_stop_words:
    nlp.vocab[w].is_stop = False


def strip_html_tags(text):
    """remove html tags from text"""
    soup = BeautifulSoup(text, "html.parser")
    stripped_text = soup.get_text(separator=" ")
    return stripped_text


def remove_whitespace(text):
    """remove extra whitespaces from text"""
    text = text.strip()
    return " ".join(text.split())


def remove_accented_chars(text):
    """remove accented characters from text, e.g. café"""
    text = unidecode.unidecode(text)
    return text


def expand_contractions(text):
    """expand shortened words, e.g. don't to do not"""
    text = list(cont.expand_texts([text], precise=True))[0]
    return text


def text_preprocessing(text, accented_chars=True, contractions=True, 
                       convert_num=True, extra_whitespace=True, 
                       lemmatization=True, lowercase=True, punctuations=False,
                       remove_html=True, remove_num=False, special_chars=False, 
                       stop_words=True):
    """preprocess text with default option set to true for all steps"""
    if remove_html == True: #remove html tags
        text = strip_html_tags(text)
    if extra_whitespace == True: #remove extra whitespaces
        text = remove_whitespace(text)
    if accented_chars == True: #remove accented characters
        text = remove_accented_chars(text)
    if contractions == True: #expand contractions
        text = expand_contractions(text)
    if lowercase == True: #convert all characters to lowercase
        text = text.lower()
    
    # return text

    doc = nlp(text) #tokenise text

    clean_text = []
    
    for token in doc:
        flag = True
        edit = token.text
        # remove stop words
        if stop_words == True and token.is_stop and token.pos_ != 'NUM': 
            flag = False
        # remove punctuations
        if punctuations == True and token.pos_ == 'PUNCT' and flag == True: 
            flag = False
        # remove special characters
        if special_chars == True and token.pos_ == 'SYM' and flag == True: 
            flag = False
        # remove numbers
        if remove_num == True and (token.pos_ == 'NUM' or token.text.isnumeric()) \
        and flag == True:
            flag = False
        # convert number words to numeric numbers
        if convert_num == True and token.pos_ == 'NUM' and flag == True:
            try:
                edit = w2n.word_to_num(token.text)
            except:
                print('error in converting number words to numeric numbers',token.text)
        # convert tokens to base form
        elif lemmatization == True and token.lemma_ != "-PRON-" and flag == True:
            edit = token.lemma_
        # append tokens edited and not removed to list 
        if edit != "" and flag == True:
            clean_text.append(edit)        
    return clean_text
# Out:
# [==================================================] 100.0% 104.8/104.8MB downloaded

# %%
def listToString(s):  
    
    # initialize an empty string 
    str1 = ""  
    
    # traverse in the string   
    for ele in s:  
        str1 += str(ele) + ' '  
    
    # return string   
    return str1

# %%
with open('/content/drive/MyDrive/Data/superuser/sup_linked_fin.json','r') as a:
    ln = pd.read_json(a,orient='table')

# %%
for i in ln.index.values:
    ln.loc[i,'Text'] = listToString(text_preprocessing(ln.loc[i,'Text'],stop_words=True))
    ln.loc[i,'Title'] = listToString(text_preprocessing(ln.loc[i,'Title'],stop_words=True))
# Out:
# Streaming output truncated to the last 5000 lines.
# error in converting number words to numeric numbers 4.8
# error in converting number words to numeric numbers 1.42.9
# error in converting number words to numeric numbers /dev
# error in converting number words to numeric numbers /dev
# error in converting number words to numeric numbers /dev
# error in converting number words to numeric numbers size=512
# error in converting number words to numeric numbers 2.0
# error in converting number words to numeric numbers 2.0
# error in converting number words to numeric numbers head=255
# error in converting number words to numeric numbers head=240
# error in converting number words to numeric numbers head=255
# error in converting number words to numeric numbers head=255
# error in converting number words to numeric numbers head=240
# error in converting number words to numeric numbers head=255
# error in converting number words to numeric numbers 0.5
# error in converting number words to numeric numbers 32-bit
# error in converting number words to numeric numbers 64-bit
# error in converting number words to numeric numbers 2.4
# error in converting number words to numeric numbers 3.4
# error in converting number words to numeric numbers 1ghz
# error in converting number words to numeric numbers 1ghz
# error in converting number words to numeric numbers 8.1
# error in converting number words to numeric numbers 2.40ghz
# error in converting number words to numeric numbers 2.4ghz
# error in converting number words to numeric numbers 133,6
# error in converting number words to numeric numbers 2405,2
# error in converting number words to numeric numbers 2.20
# error in converting number words to numeric numbers 0.6~0.8
# error in converting number words to numeric numbers 2.7~2.8
# error in converting number words to numeric numbers 2.20ghz
# error in converting number words to numeric numbers 5.9
# error in converting number words to numeric numbers 4.4
# error in converting number words to numeric numbers 4.4
# error in converting number words to numeric numbers http://unetbootin.sourceforge.net/
# error in converting number words to numeric numbers 7zip
# error in converting number words to numeric numbers 7zip
# error in converting number words to numeric numbers 06/30/2013
# error in converting number words to numeric numbers 11:44
# error in converting number words to numeric numbers 2,835,648
# error in converting number words to numeric numbers 06/05/2013
# error in converting number words to numeric numbers 12:14
# error in converting number words to numeric numbers 3,998,007,296
# error in converting number words to numeric numbers 06/04/2013
# error in converting number words to numeric numbers 03:30
# error in converting number words to numeric numbers 4,696,872,960
# error in converting number words to numeric numbers 06/05/2013
# error in converting number words to numeric numbers 01:25
# error in converting number words to numeric numbers 4,698,955,776
# error in converting number words to numeric numbers 06/30/2013
# error in converting number words to numeric numbers 11:45
# error in converting number words to numeric numbers 6,530,278
# error in converting number words to numeric numbers 06/30/2013
# error in converting number words to numeric numbers 11:46
# error in converting number words to numeric numbers 06/30/2013
# error in converting number words to numeric numbers 11:46
# error in converting number words to numeric numbers 60,928
# error in converting number words to numeric numbers 8.1
# error in converting number words to numeric numbers 8.1
# error in converting number words to numeric numbers 512-byte
# error in converting number words to numeric numbers -rename
# error in converting number words to numeric numbers |
# error in converting number words to numeric numbers |
# error in converting number words to numeric numbers \e\c
# error in converting number words to numeric numbers \eod
# error in converting number words to numeric numbers \e\c
# error in converting number words to numeric numbers \e
# error in converting number words to numeric numbers \eof
# error in converting number words to numeric numbers \eoc
# error in converting number words to numeric numbers \e
# error in converting number words to numeric numbers \e
# error in converting number words to numeric numbers \e
# error in converting number words to numeric numbers \e
# error in converting number words to numeric numbers \e
# error in converting number words to numeric numbers \eoa
# error in converting number words to numeric numbers \e\c
# error in converting number words to numeric numbers \e
# error in converting number words to numeric numbers \e\c
# error in converting number words to numeric numbers \e\c
# error in converting number words to numeric numbers 8.1
# error in converting number words to numeric numbers 8.1
# error in converting number words to numeric numbers 8.1
# error in converting number words to numeric numbers 8.1
# error in converting number words to numeric numbers 8.1
# error in converting number words to numeric numbers 8.1
# error in converting number words to numeric numbers 8.1
# error in converting number words to numeric numbers 8.1
# error in converting number words to numeric numbers 8.1
# error in converting number words to numeric numbers 8.1
# error in converting number words to numeric numbers 8.1
# error in converting number words to numeric numbers http://www.eightforums.com/tutorials/41506-wi-fi-turn-off-windows-8-a.html
# error in converting number words to numeric numbers 8.1
# error in converting number words to numeric numbers 8.1
# error in converting number words to numeric numbers 8.1
# error in converting number words to numeric numbers 8.1
# error in converting number words to numeric numbers 8.1
# error in converting number words to numeric numbers 8.1
# error in converting number words to numeric numbers 8.1
# error in converting number words to numeric numbers 8.1
# error in converting number words to numeric numbers 8.1
# error in converting number words to numeric numbers 8.1
# error in converting number words to numeric numbers 8.1
# error in converting number words to numeric numbers 14.10
# error in converting number words to numeric numbers 50.000
# error in converting number words to numeric numbers 16.04
# error in converting number words to numeric numbers 16.04
# error in converting number words to numeric numbers 10k
# error in converting number words to numeric numbers 32-bit
# error in converting number words to numeric numbers 64-bit
# error in converting number words to numeric numbers 32-bit
# error in converting number words to numeric numbers 64-bit
# error in converting number words to numeric numbers 32-bit
# error in converting number words to numeric numbers 32-bit
# error in converting number words to numeric numbers 32-bit
# error in converting number words to numeric numbers 7,8
# error in converting number words to numeric numbers 64-bit
# error in converting number words to numeric numbers 64-bit
# error in converting number words to numeric numbers 64-bit
# error in converting number words to numeric numbers 32-bit
# error in converting number words to numeric numbers 7,8
# error in converting number words to numeric numbers 64-bit
# error in converting number words to numeric numbers 8.1
# error in converting number words to numeric numbers 7/8
# error in converting number words to numeric numbers 10.04
# error in converting number words to numeric numbers 8.1
# error in converting number words to numeric numbers 8.1
# error in converting number words to numeric numbers 8.1
# error in converting number words to numeric numbers 13.152.1.1000
# error in converting number words to numeric numbers -d
# error in converting number words to numeric numbers 8.1
# error in converting number words to numeric numbers 5.5
# error in converting number words to numeric numbers 5.5
# error in converting number words to numeric numbers 2-part
# error in converting number words to numeric numbers 5.5
# error in converting number words to numeric numbers 5.5
# error in converting number words to numeric numbers 5.5
# error in converting number words to numeric numbers 192.168.1.1
# error in converting number words to numeric numbers 192.168.1.100
# error in converting number words to numeric numbers 192.168.1.149
# error in converting number words to numeric numbers 192.168.6.1
# error in converting number words to numeric numbers 192.168.6.106
# error in converting number words to numeric numbers 192.168.6.xxx
# error in converting number words to numeric numbers 192.168.1.101
# error in converting number words to numeric numbers 192.168.6.148
# error in converting number words to numeric numbers 192.168.6.106
# error in converting number words to numeric numbers 192.168.6.1
# error in converting number words to numeric numbers 192.168.1.148
# error in converting number words to numeric numbers 192.168.6.1
# error in converting number words to numeric numbers 192.168.6.1
# error in converting number words to numeric numbers 192.168.6.106
# error in converting number words to numeric numbers 192.168.6.106
# error in converting number words to numeric numbers 192.168.6.113
# error in converting number words to numeric numbers 3.5
# error in converting number words to numeric numbers 6.2.9200.16384
# error in converting number words to numeric numbers 100.0%==========================
# error in converting number words to numeric numbers 00:56:58
# error in converting number words to numeric numbers 00:56:58
# error in converting number words to numeric numbers 00:56:58
# error in converting number words to numeric numbers 00:56:58
# error in converting number words to numeric numbers 00:56:58
# error in converting number words to numeric numbers 00:56:58
# error in converting number words to numeric numbers 00:56:58
# error in converting number words to numeric numbers 00:56:58
# error in converting number words to numeric numbers 00:56:58
# error in converting number words to numeric numbers 00:56:58
# error in converting number words to numeric numbers 00:56:59
# error in converting number words to numeric numbers 00:56:59
# error in converting number words to numeric numbers 01:00:27
# error in converting number words to numeric numbers 01:00:27
# error in converting number words to numeric numbers 01:00:27
# error in converting number words to numeric numbers 01:00:27
# error in converting number words to numeric numbers 01:00:27
# error in converting number words to numeric numbers 01:00:27
# error in converting number words to numeric numbers 01:00:27
# error in converting number words to numeric numbers 00:55:06
# error in converting number words to numeric numbers 00:55:06
# error in converting number words to numeric numbers 00:55:06
# error in converting number words to numeric numbers 00:55:06
# error in converting number words to numeric numbers 00:55:06
# error in converting number words to numeric numbers 00:55:06
# error in converting number words to numeric numbers 00:55:06
# error in converting number words to numeric numbers 00:55:06
# error in converting number words to numeric numbers 00:55:06
# error in converting number words to numeric numbers 00:59:19
# error in converting number words to numeric numbers 0x00000026
# error in converting number words to numeric numbers 0x00000000000000fd
# error in converting number words to numeric numbers 81a34a10
# error in converting number words to numeric numbers 436a-89d6
# error in converting number words to numeric numbers 794b97ca407c
# error in converting number words to numeric numbers 15]"generic
# error in converting number words to numeric numbers 00:59:19
# error in converting number words to numeric numbers l:16
# error in converting number words to numeric numbers 0x01ce76b5e2626ec3
# error in converting number words to numeric numbers 00:59:19
# error in converting number words to numeric numbers 0x01ce76b5e2626ec3
# error in converting number words to numeric numbers 00:59:19
# error in converting number words to numeric numbers 122]"c:\windows\winsxs\x86_netfx35cdf
# error in converting number words to numeric numbers 139]""c:\windows\winsxs\x86_netfx35cdf
# error in converting number words to numeric numbers 00:59:20
# error in converting number words to numeric numbers 0x01ce76b5e2626ec3
# error in converting number words to numeric numbers 00:59:20
# error in converting number words to numeric numbers 00:59:20
# error in converting number words to numeric numbers 0x00000000
# error in converting number words to numeric numbers 00:59:20
# error in converting number words to numeric numbers 00:59:22
# error in converting number words to numeric numbers 00:59:22
# error in converting number words to numeric numbers 0x000000ff
# error in converting number words to numeric numbers 4096]"ddset_entry
# error in converting number words to numeric numbers 0x000000ff
# error in converting number words to numeric numbers 00:59:22
# error in converting number words to numeric numbers 0x018007
# error in converting number words to numeric numbers 81a34a10
# error in converting number words to numeric numbers 436a-89d6
# error in converting number words to numeric numbers 794b97ca407c
# error in converting number words to numeric numbers 2)[gle=0x80004005
# error in converting number words to numeric numbers 00:59:22
# error in converting number words to numeric numbers 0x80070002
# error in converting number words to numeric numbers error_file_not_found
# error in converting number words to numeric numbers 00:59:28
# error in converting number words to numeric numbers 436a-89d6
# error in converting number words to numeric numbers 794b97ca407c};netfx35cdf
# error in converting number words to numeric numbers 00:59:28
# error in converting number words to numeric numbers 01:00:26
# error in converting number words to numeric numbers 01:00:26
# error in converting number words to numeric numbers 01:00:22
# error in converting number words to numeric numbers 3.5
# error in converting number words to numeric numbers 3.5
# error in converting number words to numeric numbers .net
# error in converting number words to numeric numbers 3.5
# error in converting number words to numeric numbers 8.1
# error in converting number words to numeric numbers 8.1
# error in converting number words to numeric numbers 8.1
# error in converting number words to numeric numbers 8.1
# error in converting number words to numeric numbers 64-bit
# error in converting number words to numeric numbers 32/64-bit
# error in converting number words to numeric numbers 64-bit
# error in converting number words to numeric numbers properties->shortcut
# error in converting number words to numeric numbers 32-bit
# error in converting number words to numeric numbers http://www.yougetsignal.com/tools/open-ports/
# error in converting number words to numeric numbers -name
# error in converting number words to numeric numbers |
# error in converting number words to numeric numbers |
# error in converting number words to numeric numbers 1.xxx
# error in converting number words to numeric numbers 2.xxx
# error in converting number words to numeric numbers 1.xxx
# error in converting number words to numeric numbers 1.5
# error in converting number words to numeric numbers /dev
# error in converting number words to numeric numbers /dev
# error in converting number words to numeric numbers 192.168.0.1
# error in converting number words to numeric numbers 16-port
# error in converting number words to numeric numbers 192.168.0.1
# error in converting number words to numeric numbers 192.168.0.1
# error in converting number words to numeric numbers 192.168.1.1
# error in converting number words to numeric numbers 192.168.1.1
# error in converting number words to numeric numbers 192.168.0.99
# error in converting number words to numeric numbers 192.168.0.100
# error in converting number words to numeric numbers 192.168.0.101
# error in converting number words to numeric numbers 192.168.0.99
# error in converting number words to numeric numbers ..
# error in converting number words to numeric numbers 192.168.0.99
# error in converting number words to numeric numbers 192.168.1.1
# error in converting number words to numeric numbers 8.1
# error in converting number words to numeric numbers 8.1
# error in converting number words to numeric numbers 8.1
# error in converting number words to numeric numbers 5k750
# error in converting number words to numeric numbers 1024x640
# error in converting number words to numeric numbers 1024x768
# error in converting number words to numeric numbers 1280x800
# error in converting number words to numeric numbers -b
# error in converting number words to numeric numbers 5nrrxksb3k5sqcmh27w715ueub54fkh44mbumlckaaaadaqabaaabaqdw8xuwbvsgsxyudby+kcfsrrz
# error in converting number words to numeric numbers 1+x2
# error in converting number words to numeric numbers 9ph4dnzf6kyietktv2mj4d11zsrymxacbspuua+o6ctdegmtmwrqz3mvumvcy8ufqcepe
# error in converting number words to numeric numbers indq9q/2ijwso1e6alsiapdgogwhcq4idblwaf8xzlcacbo82js2uvsymbbcmlxpkqlbpjwinjt8
# error in converting number words to numeric numbers asn.1
# error in converting number words to numeric numbers 11cf-8056
# error in converting number words to numeric numbers 11cf-8056
# error in converting number words to numeric numbers 08002be10318
# error in converting number words to numeric numbers usbstor.sys
# error in converting number words to numeric numbers |
# error in converting number words to numeric numbers hklm\system\currentcontrolset\control\class
# error in converting number words to numeric numbers start=
# error in converting number words to numeric numbers start=
# error in converting number words to numeric numbers /cfg
# error in converting number words to numeric numbers /cfg
# error in converting number words to numeric numbers /cfg
# error in converting number words to numeric numbers /cfg
# error in converting number words to numeric numbers start=
# error in converting number words to numeric numbers start=
# error in converting number words to numeric numbers 450w
# error in converting number words to numeric numbers 2k8
# error in converting number words to numeric numbers 7.the
# error in converting number words to numeric numbers 64-bit
# error in converting number words to numeric numbers 50mbps
# error in converting number words to numeric numbers 3.6.3
# error in converting number words to numeric numbers 192.168.2.1/255.255.255.0
# error in converting number words to numeric numbers 12.04
# error in converting number words to numeric numbers /etc
# error in converting number words to numeric numbers 192.168.1.5
# error in converting number words to numeric numbers 192.168.1.5
# error in converting number words to numeric numbers 192.168.1.5
# error in converting number words to numeric numbers 255.255.255.0
# error in converting number words to numeric numbers 192.168.1.0
# error in converting number words to numeric numbers 192.168.1.254
# error in converting number words to numeric numbers 192.168.1.4
# error in converting number words to numeric numbers 12.04
# error in converting number words to numeric numbers 192.168.174.233:8000
# error in converting number words to numeric numbers 192.168.174.233
# error in converting number words to numeric numbers 192.168.2.37
# error in converting number words to numeric numbers 4.38
# error in converting number words to numeric numbers 3.2
# error in converting number words to numeric numbers 127.47
# error in converting number words to numeric numbers 1.5
# error in converting number words to numeric numbers 9l09
# error in converting number words to numeric numbers 9l09
# error in converting number words to numeric numbers 48x/48x
# error in converting number words to numeric numbers 3.20
# error in converting number words to numeric numbers 520w
# error in converting number words to numeric numbers 2008r2
# error in converting number words to numeric numbers 1024x800
# error in converting number words to numeric numbers 10/100/1000
# error in converting number words to numeric numbers 1.5
# error in converting number words to numeric numbers 7.8
# error in converting number words to numeric numbers 1.5
# error in converting number words to numeric numbers |
# error in converting number words to numeric numbers 1.7
# error in converting number words to numeric numbers 0.7.0.2
# error in converting number words to numeric numbers 2.0.0
# error in converting number words to numeric numbers 53.0.2785.80
# error in converting number words to numeric numbers 64-bit
# error in converting number words to numeric numbers 9,10
# error in converting number words to numeric numbers 3.0
# error in converting number words to numeric numbers 11,12
# error in converting number words to numeric numbers |
# error in converting number words to numeric numbers |
# error in converting number words to numeric numbers |
# error in converting number words to numeric numbers 64-bit
# error in converting number words to numeric numbers 64-bit
# error in converting number words to numeric numbers 3.5
# error in converting number words to numeric numbers 4.5
# error in converting number words to numeric numbers 7x64
# error in converting number words to numeric numbers 99.9
# error in converting number words to numeric numbers hklm\system\currentcontrolset\services\disk
# error in converting number words to numeric numbers 700mb+
# error in converting number words to numeric numbers 3.0
# error in converting number words to numeric numbers 4-port
# error in converting number words to numeric numbers 10.1.10.19
# error in converting number words to numeric numbers 255.255.255.0
# error in converting number words to numeric numbers 10.1.10.1
# error in converting number words to numeric numbers 21c5
# error in converting number words to numeric numbers 4a94
# error in converting number words to numeric numbers 8a6b-7e888650d995
# error in converting number words to numeric numbers 2001:0:9d38:6abd:14d6:2ddb
# error in converting number words to numeric numbers 1.5
# error in converting number words to numeric numbers 5.9
# error in converting number words to numeric numbers hd
# error in converting number words to numeric numbers 28,147,495
# error in converting number words to numeric numbers 28,147,495
# error in converting number words to numeric numbers 5.50
# error in converting number words to numeric numbers 1:30
# error in converting number words to numeric numbers displayed(like
# error in converting number words to numeric numbers output:-
# error in converting number words to numeric numbers /dev
# error in converting number words to numeric numbers 500.1
# error in converting number words to numeric numbers 0xd610bb10
# error in converting number words to numeric numbers 500.1
# error in converting number words to numeric numbers 2006/2007
# error in converting number words to numeric numbers 3.4
# error in converting number words to numeric numbers 9.75
# error in converting number words to numeric numbers 3.4
# error in converting number words to numeric numbers 3,4
# error in converting number words to numeric numbers 2.40ghz
# error in converting number words to numeric numbers 02:22
# error in converting number words to numeric numbers 7-zip
# error in converting number words to numeric numbers 5.00
# error in converting number words to numeric numbers 413b-9592-a10044de6cf4
# error in converting number words to numeric numbers 413b-9592-a10044de6cf4
# error in converting number words to numeric numbers hkey_classes_root\.apk\shellex\{00021500
# error in converting number words to numeric numbers 0000-c000
# error in converting number words to numeric numbers 413b-9592-a10044de6cf4
# error in converting number words to numeric numbers 11d1
# error in converting number words to numeric numbers 9a0b-00c04fc2d6c1
# error in converting number words to numeric numbers @="{c5a40261-cd64
# error in converting number words to numeric numbers 4ccf-84cb
# error in converting number words to numeric numbers 4677-a9a7
# error in converting number words to numeric numbers 4fee1f9aa000
# error in converting number words to numeric numbers 128pib
# error in converting number words to numeric numbers 32-bit
# error in converting number words to numeric numbers 48-bit
# error in converting number words to numeric numbers 20:00:09
# error in converting number words to numeric numbers 19193.944765
# error in converting number words to numeric numbers 1.5
# error in converting number words to numeric numbers 20:00:09
# error in converting number words to numeric numbers 19194.076119
# error in converting number words to numeric numbers 1.5
# error in converting number words to numeric numbers 20:00:09
# error in converting number words to numeric numbers 19194.076140
# error in converting number words to numeric numbers 1.5
# error in converting number words to numeric numbers 20:00:09
# error in converting number words to numeric numbers 19194.076151
# error in converting number words to numeric numbers 1.5
# error in converting number words to numeric numbers 20:00:09
# error in converting number words to numeric numbers 19194.076164
# error in converting number words to numeric numbers 1.5
# error in converting number words to numeric numbers 20:00:09
# error in converting number words to numeric numbers 19194.076175
# error in converting number words to numeric numbers 1.5
# error in converting number words to numeric numbers 574343374b3553584b444650
# error in converting number words to numeric numbers 20:00:09
# error in converting number words to numeric numbers 19194.077242
# error in converting number words to numeric numbers 20:00:09
# error in converting number words to numeric numbers 19194.085826
# error in converting number words to numeric numbers 1.5:1.0
# error in converting number words to numeric numbers 20:00:09
# error in converting number words to numeric numbers 1/1
# error in converting number words to numeric numbers 1.5
# error in converting number words to numeric numbers 20:00:09
# error in converting number words to numeric numbers 20:00:10
# error in converting number words to numeric numbers 19195.156098
# error in converting number words to numeric numbers 1:0:0:0
# error in converting number words to numeric numbers 20:00:10
# error in converting number words to numeric numbers 19195.157493
# error in converting number words to numeric numbers 1:0:0:0
# error in converting number words to numeric numbers 20:00:10
# error in converting number words to numeric numbers 19195.158559
# error in converting number words to numeric numbers 1:0:0:0
# error in converting number words to numeric numbers 512-byte
# error in converting number words to numeric numbers 2.20
# error in converting number words to numeric numbers 20:00:10
# error in converting number words to numeric numbers 19195.159885
# error in converting number words to numeric numbers 1:0:0:0
# error in converting number words to numeric numbers 20:00:10
# error in converting number words to numeric numbers 19195.160909
# error in converting number words to numeric numbers 1:0:0:0
# error in converting number words to numeric numbers 20:00:10
# error in converting number words to numeric numbers 19195.160926
# error in converting number words to numeric numbers 1:0:0:0
# error in converting number words to numeric numbers 20:00:10
# error in converting number words to numeric numbers 19195.189942
# error in converting number words to numeric numbers 1:0:0:0
# error in converting number words to numeric numbers 20:00:10
# error in converting number words to numeric numbers /dev
# error in converting number words to numeric numbers wcc7k5sxkdfp
# error in converting number words to numeric numbers 80.00a80
# error in converting number words to numeric numbers 2.5
# error in converting number words to numeric numbers 2.6
# error in converting number words to numeric numbers 3.0
# error in converting number words to numeric numbers 0x006d
# error in converting number words to numeric numbers 4.+
# error in converting number words to numeric numbers 64-bit
# error in converting number words to numeric numbers 8460p
# error in converting number words to numeric numbers 32-bit
# error in converting number words to numeric numbers 8.0
# error in converting number words to numeric numbers 10.000.000
# error in converting number words to numeric numbers 300'000
# error in converting number words to numeric numbers 450k+
# error in converting number words to numeric numbers 8dot3names
# error in converting number words to numeric numbers 1/2
# error in converting number words to numeric numbers 3.0
# error in converting number words to numeric numbers 7.0.2
# error in converting number words to numeric numbers cflags=
# error in converting number words to numeric numbers ldflags=
# error in converting number words to numeric numbers 17.103
# error in converting number words to numeric numbers 17.103
# error in converting number words to numeric numbers 24.102
# error in converting number words to numeric numbers 24.102
# error in converting number words to numeric numbers 25.100
# error in converting number words to numeric numbers 25.100
# error in converting number words to numeric numbers 0.101
# error in converting number words to numeric numbers 0.101
# error in converting number words to numeric numbers 31.100
# error in converting number words to numeric numbers 31.100
# error in converting number words to numeric numbers 0.100
# error in converting number words to numeric numbers 0.100
# error in converting number words to numeric numbers 0.101
# error in converting number words to numeric numbers 0.101
# error in converting number words to numeric numbers 0.100
# error in converting number words to numeric numbers 0.100
# error in converting number words to numeric numbers 0.023220
# error in converting number words to numeric numbers 0:0(und
# error in converting number words to numeric numbers 1280x720
# error in converting number words to numeric numbers 16:9
# error in converting number words to numeric numbers 29.97
# error in converting number words to numeric numbers 29.97
# error in converting number words to numeric numbers 59.94
# error in converting number words to numeric numbers 1:0
# error in converting number words to numeric numbers 0:0(und
# error in converting number words to numeric numbers 33][0][0][0
# error in converting number words to numeric numbers 1280x720
# error in converting number words to numeric numbers 16:9
# error in converting number words to numeric numbers 29.97
# error in converting number words to numeric numbers 29.97
# error in converting number words to numeric numbers 64][0][0][0
# error in converting number words to numeric numbers 0:2
# error in converting number words to numeric numbers 0:0
# error in converting number words to numeric numbers 0:0
# error in converting number words to numeric numbers 0:1
# error in converting number words to numeric numbers 1:0
# error in converting number words to numeric numbers 0:2
# error in converting number words to numeric numbers frame=
# error in converting number words to numeric numbers size=
# error in converting number words to numeric numbers frame=
# error in converting number words to numeric numbers frame=
# error in converting number words to numeric numbers size=
# error in converting number words to numeric numbers frame=
# error in converting number words to numeric numbers size=
# error in converting number words to numeric numbers frame=
# error in converting number words to numeric numbers size=
# error in converting number words to numeric numbers frame=
# error in converting number words to numeric numbers size=
# error in converting number words to numeric numbers frame=
# error in converting number words to numeric numbers fps=559
# error in converting number words to numeric numbers size=
# error in converting number words to numeric numbers frame=
# error in converting number words to numeric numbers size=
# error in converting number words to numeric numbers frame=
# error in converting number words to numeric numbers size=
# error in converting number words to numeric numbers frame=
# error in converting number words to numeric numbers size=
# error in converting number words to numeric numbers frame=
# error in converting number words to numeric numbers size=
# error in converting number words to numeric numbers frame=
# error in converting number words to numeric numbers size=
# error in converting number words to numeric numbers frame=
# error in converting number words to numeric numbers size=
# error in converting number words to numeric numbers frame=
# error in converting number words to numeric numbers size=
# error in converting number words to numeric numbers frame=
# error in converting number words to numeric numbers size=
# error in converting number words to numeric numbers frame=
# error in converting number words to numeric numbers size=
# error in converting number words to numeric numbers frame=
# error in converting number words to numeric numbers size=
# error in converting number words to numeric numbers frame=
# error in converting number words to numeric numbers fps=559
# error in converting number words to numeric numbers size=
# error in converting number words to numeric numbers frame=
# error in converting number words to numeric numbers size=
# error in converting number words to numeric numbers frame=
# error in converting number words to numeric numbers size=
# error in converting number words to numeric numbers frame=
# error in converting number words to numeric numbers size=
# error in converting number words to numeric numbers frame=
# error in converting number words to numeric numbers size=
# error in converting number words to numeric numbers frame=
# error in converting number words to numeric numbers size=
# error in converting number words to numeric numbers frame=
# error in converting number words to numeric numbers size=
# error in converting number words to numeric numbers frame=
# error in converting number words to numeric numbers size=
# error in converting number words to numeric numbers frame=
# error in converting number words to numeric numbers size=
# error in converting number words to numeric numbers frame=
# error in converting number words to numeric numbers size=
# error in converting number words to numeric numbers frame=
# error in converting number words to numeric numbers size=
# error in converting number words to numeric numbers frame=
# error in converting number words to numeric numbers size=
# error in converting number words to numeric numbers frame=
# error in converting number words to numeric numbers size=
# error in converting number words to numeric numbers frame=
# error in converting number words to numeric numbers size=
# error in converting number words to numeric numbers frame=
# error in converting number words to numeric numbers size=
# error in converting number words to numeric numbers frame=
# error in converting number words to numeric numbers fps=559
# error in converting number words to numeric numbers size=
# error in converting number words to numeric numbers frame=
# error in converting number words to numeric numbers size=
# error in converting number words to numeric numbers frame=
# error in converting number words to numeric numbers size=
# error in converting number words to numeric numbers size=
# error in converting number words to numeric numbers size=
# error in converting number words to numeric numbers size=
# error in converting number words to numeric numbers size=
# error in converting number words to numeric numbers size=
# error in converting number words to numeric numbers frame=11337
# error in converting number words to numeric numbers size=
# error in converting number words to numeric numbers size=
# error in converting number words to numeric numbers size=
# error in converting number words to numeric numbers size=
# error in converting number words to numeric numbers size=
# error in converting number words to numeric numbers size=
# error in converting number words to numeric numbers size=
# error in converting number words to numeric numbers size=
# error in converting number words to numeric numbers size=
# error in converting number words to numeric numbers 0.627264
# error in converting number words to numeric numbers 6.2.9200.16628
# error in converting number words to numeric numbers 51a94434
# error in converting number words to numeric numbers 6.2.9200.16579
# error in converting number words to numeric numbers 6.2.9200.16384
# error in converting number words to numeric numbers 0x5010a827
# error in converting number words to numeric numbers 6.2.9200.16451
# error in converting number words to numeric numbers 0x50988aa6
# error in converting number words to numeric numbers 188b1b81-f6eb-11e2-be89
# error in converting number words to numeric numbers 60eb69184d3d
# error in converting number words to numeric numbers 8007274c
# error in converting number words to numeric numbers e9a99e36-f6ba-11e2-be89
# error in converting number words to numeric numbers 21.0.1180.89
# error in converting number words to numeric numbers bootup
# error in converting number words to numeric numbers bootup
# error in converting number words to numeric numbers 10mbps
# error in converting number words to numeric numbers 8.1
# error in converting number words to numeric numbers 4.3.16
# error in converting number words to numeric numbers 8.1
# error in converting number words to numeric numbers 7/8
# error in converting number words to numeric numbers display->screen
# error in converting number words to numeric numbers --git
# error in converting number words to numeric numbers dir="d:/documents/.git
# error in converting number words to numeric numbers -requestsoverride
# error in converting number words to numeric numbers environmentvariabletarget]::user
# error in converting number words to numeric numbers 6.4.3
# error in converting number words to numeric numbers 6.4.3
# error in converting number words to numeric numbers 4,000
# error in converting number words to numeric numbers 300,000
# error in converting number words to numeric numbers 8.0/8.1
# error in converting number words to numeric numbers 1200.23mhz
# error in converting number words to numeric numbers 133mhz
# error in converting number words to numeric numbers 18.55
# error in converting number words to numeric numbers 15.66
# error in converting number words to numeric numbers 9.89
# error in converting number words to numeric numbers 8.54
# error in converting number words to numeric numbers 6.93
# error in converting number words to numeric numbers 6.11
# error in converting number words to numeric numbers 4.2
# error in converting number words to numeric numbers 1347142115.exe
# error in converting number words to numeric numbers 32-bit
# error in converting number words to numeric numbers us/46a867a0
# error in converting number words to numeric numbers 4b90-abe3
# error in converting number words to numeric numbers 9a5661d1b276
# error in converting number words to numeric numbers 1-line
# error in converting number words to numeric numbers -trigger
# error in converting number words to numeric numbers -program
# error in converting number words to numeric numbers 6/10/2013
# error in converting number words to numeric numbers 10:47:00
# error in converting number words to numeric numbers 6/10/2013
# error in converting number words to numeric numbers 10:47:00
# error in converting number words to numeric numbers 6/10/2013
# error in converting number words to numeric numbers 10:47:00
# error in converting number words to numeric numbers 6/10/2013
# error in converting number words to numeric numbers 10:47:00
# error in converting number words to numeric numbers 6/10/2013
# error in converting number words to numeric numbers 10:47:00
# error in converting number words to numeric numbers 6/10/2013
# error in converting number words to numeric numbers 10:47:00
# error in converting number words to numeric numbers 6/10/2013
# error in converting number words to numeric numbers 10:47:00
# error in converting number words to numeric numbers 1:26
# error in converting number words to numeric numbers 3.click
# error in converting number words to numeric numbers vmwareplayer_x64.msi
# error in converting number words to numeric numbers 5.1
# error in converting number words to numeric numbers 01:00:22:709
# error in converting number words to numeric numbers 01:00:22:725
# error in converting number words to numeric numbers 01:00:22:725
# error in converting number words to numeric numbers 3.5
# error in converting number words to numeric numbers mm
# error in converting number words to numeric numbers 3.5
# error in converting number words to numeric numbers :)
# error in converting number words to numeric numbers 100.112.96.1
# error in converting number words to numeric numbers 255.255.252.0
# error in converting number words to numeric numbers 255.255.254.0
# error in converting number words to numeric numbers 7d
# error in converting number words to numeric numbers 1b
# error in converting number words to numeric numbers 8f
# error in converting number words to numeric numbers 7d
# error in converting number words to numeric numbers 1b
# error in converting number words to numeric numbers 4f
# error in converting number words to numeric numbers 7d
# error in converting number words to numeric numbers 1b
# error in converting number words to numeric numbers 0.0.0.0
# error in converting number words to numeric numbers 0.0.0.0
# error in converting number words to numeric numbers 100.112.96.1
# error in converting number words to numeric numbers 100.112.98.101
# error in converting number words to numeric numbers 100.112.96.0
# error in converting number words to numeric numbers 255.255.252.0
# error in converting number words to numeric numbers 100.112.98.101
# error in converting number words to numeric numbers 100.112.98.101
# error in converting number words to numeric numbers 255.255.255.255
# error in converting number words to numeric numbers 100.112.98.101
# error in converting number words to numeric numbers 100.112.99.255
# error in converting number words to numeric numbers 255.255.255.255
# error in converting number words to numeric numbers 100.112.98.101
# error in converting number words to numeric numbers 127.0.0.0
# error in converting number words to numeric numbers 255.255.255.255
# error in converting number words to numeric numbers 127.255.255.255
# error in converting number words to numeric numbers 255.255.255.255
# error in converting number words to numeric numbers 172.0.0.0
# error in converting number words to numeric numbers 172.16.123.231
# error in converting number words to numeric numbers 172.16.0.0
# error in converting number words to numeric numbers 172.16.123.231
# error in converting number words to numeric numbers 255.255.254.0
# error in converting number words to numeric numbers 172.16.123.231
# error in converting number words to numeric numbers 172.16.123.231
# error in converting number words to numeric numbers 255.255.255.255
# error in converting number words to numeric numbers 172.16.123.231
# error in converting number words to numeric numbers 172.16.123.255
# error in converting number words to numeric numbers 255.255.255.255
# error in converting number words to numeric numbers 172.16.123.231
# error in converting number words to numeric numbers 240.0.0.0
# error in converting number words to numeric numbers 240.0.0.0
# error in converting number words to numeric numbers 100.112.98.101
# error in converting number words to numeric numbers 240.0.0.0
# error in converting number words to numeric numbers 172.16.123.231
# error in converting number words to numeric numbers 255.255.255.255
# error in converting number words to numeric numbers 255.255.255.255
# error in converting number words to numeric numbers 255.255.255.255
# error in converting number words to numeric numbers 255.255.255.255
# error in converting number words to numeric numbers 100.112.98.101
# error in converting number words to numeric numbers 255.255.255.255
# error in converting number words to numeric numbers 255.255.255.255
# error in converting number words to numeric numbers 172.16.123.231
# error in converting number words to numeric numbers 0.0.0.0
# error in converting number words to numeric numbers 0.0.0.0
# error in converting number words to numeric numbers 100.112.96.1
# error in converting number words to numeric numbers 172.16.0.0
# error in converting number words to numeric numbers 1/128
# error in converting number words to numeric numbers 0.0.0.0
# error in converting number words to numeric numbers 172.16.0.30
# error in converting number words to numeric numbers 172.16.xxx.xxx
# error in converting number words to numeric numbers 0.0.0.0
# error in converting number words to numeric numbers 172.16.0.30
# error in converting number words to numeric numbers 1:30am
# error in converting number words to numeric numbers 6:30am
# error in converting number words to numeric numbers 6:30
# error in converting number words to numeric numbers 7:00
# error in converting number words to numeric numbers 6:30
# error in converting number words to numeric numbers 8.8.8.8
# error in converting number words to numeric numbers 8.8.8.8
# error in converting number words to numeric numbers 8.8.8.8
# error in converting number words to numeric numbers 6.1.7601
# error in converting number words to numeric numbers 8.8.8.8
# error in converting number words to numeric numbers 8.8.8.8
# error in converting number words to numeric numbers 2a00:1450:4017:801::1006
# error in converting number words to numeric numbers 212.199.205.232
# error in converting number words to numeric numbers 212.199.205.242
# error in converting number words to numeric numbers 212.199.205.222
# error in converting number words to numeric numbers 212.199.205.237
# error in converting number words to numeric numbers 212.199.205.231
# error in converting number words to numeric numbers 212.199.205.241
# error in converting number words to numeric numbers 212.199.205.212
# error in converting number words to numeric numbers 212.199.205.227
# error in converting number words to numeric numbers 212.199.205.247
# error in converting number words to numeric numbers 212.199.205.246
# error in converting number words to numeric numbers 212.199.205.251
# error in converting number words to numeric numbers 212.199.205.221
# error in converting number words to numeric numbers 212.199.205.217
# error in converting number words to numeric numbers 212.199.205.236
# error in converting number words to numeric numbers 212.199.205.226
# error in converting number words to numeric numbers 212.199.205.216
# error in converting number words to numeric numbers c:\users\asdf
# error in converting number words to numeric numbers 6.1.7601
# error in converting number words to numeric numbers c:\users\asdf
# error in converting number words to numeric numbers 1.0.0.127.in
# error in converting number words to numeric numbers 2a00:1450:4017:800::1008
# error in converting number words to numeric numbers 212.199.205.242
# error in converting number words to numeric numbers 212.199.205.247
# error in converting number words to numeric numbers 212.199.205.237
# error in converting number words to numeric numbers 212.199.205.232
# error in converting number words to numeric numbers 212.199.205.231
# error in converting number words to numeric numbers 212.199.205.226
# error in converting number words to numeric numbers 212.199.205.217
# error in converting number words to numeric numbers 212.199.205.212
# error in converting number words to numeric numbers 212.199.205.227
# error in converting number words to numeric numbers 212.199.205.241
# error in converting number words to numeric numbers 212.199.205.236
# error in converting number words to numeric numbers 212.199.205.246
# error in converting number words to numeric numbers 212.199.205.216
# error in converting number words to numeric numbers 212.199.205.251
# error in converting number words to numeric numbers 212.199.205.221
# error in converting number words to numeric numbers 212.199.205.222
# error in converting number words to numeric numbers c:\users\asdf
# error in converting number words to numeric numbers user@host:~$
# error in converting number words to numeric numbers 8.8.8.8
# error in converting number words to numeric numbers 8.8.8.8
# error in converting number words to numeric numbers 8.8.4.4
# error in converting number words to numeric numbers 8.8.4.4
# error in converting number words to numeric numbers 8.8.8.8
# error in converting number words to numeric numbers 8.8.8.8
# error in converting number words to numeric numbers 104.16.32.193
# error in converting number words to numeric numbers 104.16.125.192
# error in converting number words to numeric numbers 104.16.126.192
# error in converting number words to numeric numbers 104.16.127.192
# ...
# error in converting number words to numeric numbers 0.013
# error in converting number words to numeric numbers 4.4.35
# error in converting number words to numeric numbers 1-pve
# error in converting number words to numeric numbers 11:09:55
# error in converting number words to numeric numbers 8.9
# error in converting number words to numeric numbers xx
# error in converting number words to numeric numbers 88.0
# error in converting number words to numeric numbers 10.6
# error in converting number words to numeric numbers mask:255.255.255.0
# error in converting number words to numeric numbers 146.0
# error in converting number words to numeric numbers 33.3
# error in converting number words to numeric numbers xx
# error in converting number words to numeric numbers 413.6
# error in converting number words to numeric numbers 92.3
# error in converting number words to numeric numbers xx
# error in converting number words to numeric numbers 42.8
# error in converting number words to numeric numbers 13.2
# error in converting number words to numeric numbers xx
# error in converting number words to numeric numbers addr:198.51.100.206
# error in converting number words to numeric numbers 81.7
# error in converting number words to numeric numbers 3.8
# error in converting number words to numeric numbers mask:255.0.0.0
# error in converting number words to numeric numbers 22.3
# error in converting number words to numeric numbers 22.3
# error in converting number words to numeric numbers 255.255.255.0
# error in converting number words to numeric numbers 128.66.100.0
# error in converting number words to numeric numbers 0.0.0.0
# error in converting number words to numeric numbers 255.255.255.0
# error in converting number words to numeric numbers 203.0.113.0
# error in converting number words to numeric numbers 0.0.0.0
# error in converting number words to numeric numbers 255.255.255.0
# error in converting number words to numeric numbers 0.0.0.0
# error in converting number words to numeric numbers 255.255.255.0
# error in converting number words to numeric numbers 198.51.100.0
# error in converting number words to numeric numbers 0.0.0.0
# error in converting number words to numeric numbers 255.255.255.0
# error in converting number words to numeric numbers 128.66.200.10/32
# error in converting number words to numeric numbers 128.66.100.10/32
# error in converting number words to numeric numbers 255.255.255.0
# error in converting number words to numeric numbers 203.0.113.0
# error in converting number words to numeric numbers 0.0.0.0
# error in converting number words to numeric numbers 255.255.255.0
# error in converting number words to numeric numbers 198.51.100.0
# error in converting number words to numeric numbers 0.0.0.0
# error in converting number words to numeric numbers 255.255.255.0
# error in converting number words to numeric numbers 128.66.100.0
# error in converting number words to numeric numbers 0.0.0.0
# error in converting number words to numeric numbers 255.255.255.0
# error in converting number words to numeric numbers 128.66.100.10
# error in converting number words to numeric numbers 128.66.200.1
# error in converting number words to numeric numbers 255.255.255.255
# error in converting number words to numeric numbers 0.0.0.0
# error in converting number words to numeric numbers 255.255.255.0
# error in converting number words to numeric numbers 128.66.200.10
# error in converting number words to numeric numbers 255.255.255.255
# error in converting number words to numeric numbers 128.66.100.10
# error in converting number words to numeric numbers 128.66.100.10
# error in converting number words to numeric numbers 128.66.100.10
# error in converting number words to numeric numbers 56(84
# error in converting number words to numeric numbers 128.66.100.10
# error in converting number words to numeric numbers 128.66.100.10
# error in converting number words to numeric numbers 128.66.100.10
# error in converting number words to numeric numbers 128.66.100.10
# error in converting number words to numeric numbers 8/17/2017
# error in converting number words to numeric numbers 8:12
# error in converting number words to numeric numbers 128.66.100.10/24
# error in converting number words to numeric numbers 128.66.200.10/24
# error in converting number words to numeric numbers 128.66.100.0
# error in converting number words to numeric numbers 255.255.255.0
# error in converting number words to numeric numbers 128.66.100.10
# error in converting number words to numeric numbers 128.66.200.1
# error in converting number words to numeric numbers 255.255.255.255
# error in converting number words to numeric numbers 0.0.0.0
# error in converting number words to numeric numbers 255.255.255.0
# error in converting number words to numeric numbers 128.66.200.10
# error in converting number words to numeric numbers 255.255.255.255
# error in converting number words to numeric numbers 128.66.100.10
# error in converting number words to numeric numbers 128.66.100.10
# error in converting number words to numeric numbers 128.66.100.0
# error in converting number words to numeric numbers 255.255.255.0
# error in converting number words to numeric numbers 128.66.100.10
# error in converting number words to numeric numbers 128.66.200.1
# error in converting number words to numeric numbers 255.255.255.255
# error in converting number words to numeric numbers 128.66.100.10
# error in converting number words to numeric numbers 128.66.200.1
# error in converting number words to numeric numbers 255.255.255.255
# error in converting number words to numeric numbers 8/21/2017
# error in converting number words to numeric numbers 4.4
# error in converting number words to numeric numbers 8/27/2017
# error in converting number words to numeric numbers 8/27/2017
# error in converting number words to numeric numbers 192.168.1.10
# error in converting number words to numeric numbers 192.168.2.10
# error in converting number words to numeric numbers 0,100,200
# error in converting number words to numeric numbers 0-value
# error in converting number words to numeric numbers 4ghz
# error in converting number words to numeric numbers 4ghz
# error in converting number words to numeric numbers 4ghz
# error in converting number words to numeric numbers 4790k
# error in converting number words to numeric numbers 4.00ghz
# error in converting number words to numeric numbers 4790k
# error in converting number words to numeric numbers 4ghz
# error in converting number words to numeric numbers 2.5
# error in converting number words to numeric numbers -x509
# error in converting number words to numeric numbers -nodes
# error in converting number words to numeric numbers \
# error in converting number words to numeric numbers \
# error in converting number words to numeric numbers -newkey
# error in converting number words to numeric numbers -days
# error in converting number words to numeric numbers \
# error in converting number words to numeric numbers -keyout
# error in converting number words to numeric numbers 0/1
# error in converting number words to numeric numbers 8.8.8.8
# error in converting number words to numeric numbers 8.8.8.8
# error in converting number words to numeric numbers 8.8.8.8
# error in converting number words to numeric numbers 8.8.8.8
# error in converting number words to numeric numbers 8.8.8.8
# error in converting number words to numeric numbers 8.8.8.8
# error in converting number words to numeric numbers 10.12.44.16
# error in converting number words to numeric numbers 8.8.8.8
# error in converting number words to numeric numbers 8.8.8.8
# error in converting number words to numeric numbers 8.8.8.8
# error in converting number words to numeric numbers 8.8.8.8
# error in converting number words to numeric numbers 8.8.8.8
# error in converting number words to numeric numbers 10.0.1.15
# error in converting number words to numeric numbers 8.8.8.8
# error in converting number words to numeric numbers 8.8.8.8
# error in converting number words to numeric numbers 8.8.8.8
# error in converting number words to numeric numbers 60:03:08:8b:96:88
# error in converting number words to numeric numbers 0x5
# error in converting number words to numeric numbers 10.0.1.15
# error in converting number words to numeric numbers 10.0.1.255
# error in converting number words to numeric numbers options=201
# error in converting number words to numeric numbers 10.12.44.16
# error in converting number words to numeric numbers 10.12.44.16
# error in converting number words to numeric numbers 10.0.1.1
# error in converting number words to numeric numbers 10.0.1.1
# error in converting number words to numeric numbers 0:24:36
# error in converting number words to numeric numbers 64.120.44.114/32
# error in converting number words to numeric numbers 10.0.1.1
# error in converting number words to numeric numbers 0/1
# error in converting number words to numeric numbers 10.12.44.1
# error in converting number words to numeric numbers 10.12.44.1
# error in converting number words to numeric numbers 10.12.44/22
# error in converting number words to numeric numbers 10.12.44.16
# error in converting number words to numeric numbers 10.12.44.16
# error in converting number words to numeric numbers 10.12.44.16
# error in converting number words to numeric numbers ~/.bashrc
# error in converting number words to numeric numbers 4k
# error in converting number words to numeric numbers 4k
# error in converting number words to numeric numbers 4k
# error in converting number words to numeric numbers 4k
# error in converting number words to numeric numbers 4k
# error in converting number words to numeric numbers 4k
# error in converting number words to numeric numbers 10.11.6
# error in converting number words to numeric numbers 4k
# error in converting number words to numeric numbers 4k
# error in converting number words to numeric numbers 1080p
# error in converting number words to numeric numbers 1080p
# error in converting number words to numeric numbers 2.3ghz
# error in converting number words to numeric numbers -batch
# error in converting number words to numeric numbers -x509
# error in converting number words to numeric numbers -nodes
# error in converting number words to numeric numbers -days
# error in converting number words to numeric numbers -config
# error in converting number words to numeric numbers private/$domain.key
# error in converting number words to numeric numbers -batch
# error in converting number words to numeric numbers private/$domain.key
# error in converting number words to numeric numbers -config
# error in converting number words to numeric numbers -subj
# error in converting number words to numeric numbers /commonname=$domain
# error in converting number words to numeric numbers -cakey
# error in converting number words to numeric numbers -cacreateserial
# error in converting number words to numeric numbers certs/$domain.crt
# error in converting number words to numeric numbers -days
# error in converting number words to numeric numbers certs/$domain.crt
# error in converting number words to numeric numbers /etc
# error in converting number words to numeric numbers error([('ssl
# error in converting number words to numeric numbers -host
# error in converting number words to numeric numbers -port
# error in converting number words to numeric numbers -prexit
# error in converting number words to numeric numbers -showcerts
# error in converting number words to numeric numbers -capath
# error in converting number words to numeric numbers -verbose
# error in converting number words to numeric numbers -cafile
# error in converting number words to numeric numbers 16.04
# error in converting number words to numeric numbers -showcerts
# error in converting number words to numeric numbers /dev
# error in converting number words to numeric numbers -noout
# error in converting number words to numeric numbers 192.168.0.103
# error in converting number words to numeric numbers 255.255.255.0
# error in converting number words to numeric numbers 192.168.0.1
# error in converting number words to numeric numbers 192.168.33.255
# error in converting number words to numeric numbers 192.168.33.1
# error in converting number words to numeric numbers 255.255.255.0
# error in converting number words to numeric numbers 192.168.33.2
# error in converting number words to numeric numbers 255.255.255.0
# error in converting number words to numeric numbers 192.168.33.3
# error in converting number words to numeric numbers 192.168.33.254
# error in converting number words to numeric numbers 192.168.33.3
# error in converting number words to numeric numbers 192.168.33.3
# error in converting number words to numeric numbers 192.168.33.3
# error in converting number words to numeric numbers 192.168.33.3
# error in converting number words to numeric numbers 192.168.33.3
# error in converting number words to numeric numbers 192.168.0.103
# error in converting number words to numeric numbers 192.168.0.3
# error in converting number words to numeric numbers 192.168.0.103
# error in converting number words to numeric numbers 192.168.33.1
# error in converting number words to numeric numbers 192.168.33.1
# error in converting number words to numeric numbers 192.168.33.1
# error in converting number words to numeric numbers 56(84
# error in converting number words to numeric numbers 192.168.33.1
# error in converting number words to numeric numbers time=0.378
# error in converting number words to numeric numbers 192.168.33.1
# error in converting number words to numeric numbers ttl=128
# error in converting number words to numeric numbers 2500k
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-f8c9ca24b0d7> in <module>()
#       1 for i in ln.index.values:
# ----> 2     ln.loc[i,'Text'] = listToString(text_preprocessing(ln.loc[i,'Text'],stop_words=True))
#       3     ln.loc[i,'Title'] = listToString(text_preprocessing(ln.loc[i,'Title'],stop_words=True))
#
# <ipython-input-5-c2d4a5a37faa> in text_preprocessing(text, accented_chars, contractions, convert_num, extra_whitespace, lemmatization, lowercase, punctuations, remove_html, remove_num, special_chars, stop_words)
#      53         text = remove_accented_chars(text)
#      54     if contractions == True: #expand contractions
# ---> 55         text = expand_contractions(text)
#      56     if lowercase == True: #convert all characters to lowercase
#      57         text = text.lower()
#
# <ipython-input-5-c2d4a5a37faa> in expand_contractions(text)
#      36 def expand_contractions(text):
#      37     """expand shortened words, e.g. don't to do not"""
# ---> 38     text = list(cont.expand_texts([text], precise=True))[0]
#      39     return text
#      40
#
# /usr/local/lib/python3.7/dist-packages/pycontractions/contractions.py in expand_texts(self, texts, precise, scores)
#     397
#     398         for text in texts:
# --> 399             text, intermediates = _fn(text, scores)
#     400             if scores:
#     401                 yield intermediates
#
# /usr/local/lib/python3.7/dist-packages/pycontractions/contractions.py in _expand_text_precise(self, text, scores)
#     365                 # This performs (n+m-1)! / m! / (n-1)! total iterations
#     366                 for perm_set in (set(permutations(comb)) for comb in combinations_with_replacement(options,
# --> 367                                                                                                    num_matches)):
#     368                     # This performs sum(n * m! / (m-x)! * (x+1) for x in range(m)) total iterations
#     369                     for perm in perm_set:
#
# /usr/local/lib/python3.7/dist-packages/pycontractions/contractions.py in <genexpr>(.0)
#     364                 # If n = len(options) and m = num_matches:
#     365                 # This performs (n+m-1)! / m! / (n-1)! total iterations
# --> 366                 for perm_set in (set(permutations(comb)) for comb in combinations_with_replacement(options,
#     367                                                                                                    num_matches)):
#     368                     # This performs sum(n * m! / (m-x)! * (x+1) for x in range(m)) total iterations
#
# KeyboardInterrupt:

# %%
with open('/content/drive/MyDrive/Data/superuser/sup_linked_fin_nosw.json','w') as a:
    ln.to_json(a,orient='table')

# %%
with open('/content/drive/MyDrive/Data/Data_Missing.txt','r',encoding='utf-8') as fi:
    s = fi.read()
    s_split = re.split('\?|\n',s)
    final_with_stopwords = ''
    final_without_stopwords = ''
    for i in range(0,len(s_split)):
        final_with_stopwords = listToString(text_preprocessing(s_split[i],stop_words=False)) + '\n'
        final_without_stopwords = listToString(text_preprocessing(s_split[i],stop_words=True)) + '\n'
        with open('/content/drive/MyDrive/Data/data_missing_with_stopwords.txt','a') as f:
            f.write(final_with_stopwords) 
        with open('/content/drive/MyDrive/Data/data_missing_without_stopwords.txt','a') as f:
            f.write(final_without_stopwords) 
    print(final_with_stopwords[:100])
    print(final_without_stopwords[:100])

# %% [markdown]
# This Notebook is based on tutorial https://www.youtube.com/watch?v=s-3zts7FTDA
#
# Corresponding Kaggle Notebook : https://www.kaggle.com/abhishek/training-language-models-on-tpus-from-scratch/comments

# %%
! pip install -U tokenizers==0.4.2
# Out:
# ...
#      |████████████████████████████████| 3.7MB 3.3MB/s
# ...

# %%
# !pip install transformers==2.4.1
# Out:
# ...
#      |████████████████████████████████| 481kB 3.3MB/s
# ...
#      |████████████████████████████████| 3.1MB 7.5MB/s
# ...
#      |████████████████████████████████| 1.1MB 30.6MB/s
# ...
#      |████████████████████████████████| 890kB 45.2MB/s
# ...
#      |████████████████████████████████| 133kB 34.5MB/s
# ...
#      |████████████████████████████████| 6.7MB 37.7MB/s
# ...
#      |████████████████████████████████| 71kB 6.9MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893257 sha256=dc9049c95620427ccc0996a599695a344c3e900cd4e1ba4ae165fcc0ce7a0f86
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# ERROR: botocore 1.19.4 has requirement urllib3<1.26,>=1.25.4; python_version != "3.4", but you'll have urllib3 1.24.3 which is incompatible.
# ...
#   Found existing installation: tokenizers 0.4.2
#     Uninstalling tokenizers-0.4.2:
#       Successfully uninstalled tokenizers-0.4.2
# ...

# %%
# Out:
# ...
#      |████████████████████████████████| 412.3MB 35kB/s
# ...
#      |████████████████████████████████| 512kB 37.1MB/s
# ...
#      |████████████████████████████████| 51kB 4.7MB/s
# ...
#      |████████████████████████████████| 3.8MB 37.1MB/s
# ...
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7542 sha256=8f9f89703bcbfd110ee7dd1e8e94531181dcfeb846025cf704bec7b35b27a763
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# ERROR: tensorflow-probability 0.11.0 has requirement gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.
# ...
#   Found existing installation: tensorflow-estimator 2.3.0
#     Uninstalling tensorflow-estimator-2.3.0:
#       Successfully uninstalled tensorflow-estimator-2.3.0
#   Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
#   Found existing installation: tensorboard 2.3.0
# ...

# %%
# %tensorflow_version 1.x
import tensorflow as tf
print("Tensorflow version " + tf.__version__)

try:
  tpu = tf.distribute.cluster_resolver.TPUClusterResolver()  # TPU detection
  print('Running on TPU ', tpu.cluster_spec().as_dict()['worker'])
except ValueError:
  raise BaseException('ERROR: Not connected to a TPU runtime; please see the previous cell in this notebook for instructions!')

tf.config.experimental_connect_to_cluster(tpu)
tf.tpu.experimental.initialize_tpu_system(tpu)
tpu_strategy = tf.distribute.experimental.TPUStrategy(tpu)
# Out:
# TensorFlow 1.x selected.
# Tensorflow version 1.15.2
# Running on TPU  ['10.18.239.194:8470']
# INFO:tensorflow:Initializing the TPU system: 10.18.239.194:8470
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Querying Tensorflow master (grpc://10.18.239.194:8470) for TPU system metadata.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, -1, 10952929999779506208)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 17179869184, 12992848035366870823)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 17179869184, 5190887444832307509)
# ...

# %%
# import tokenizers
# from typing import Optional, List, Union, Dict

# %%
# bwpt = tokenizers.BertWordPieceTokenizer(
#     vocab_file=None,
#     add_special_tokens=True,
#     unk_token='[UNK]',
#     sep_token='[SEP]',
#     cls_token='[CLS]',
#     clean_text=True,
#     handle_chinese_chars=True,
#     strip_accents=True,
#     lowercase=True,
#     wordpieces_prefix='##'
# )
# bwpt
# Out:
# Tokenizer(vocabulary_size=3, model=BertWordPiece, add_special_tokens=True, unk_token=[UNK], sep_token=[SEP], cls_token=[CLS], clean_text=True, handle_chinese_chars=True, strip_accents=True, lowercase=True, wordpieces_prefix=##)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# bwpt.train(
#     files=["/content/drive/My Drive/Data/text_corpus2.txt"],
#     vocab_size=30000,
#     min_frequency=3,
#     limit_alphabet=1000,
#     special_tokens=['[PAD]', '[UNK]', '[CLS]', '[MASK]', '[SEP]']
# )

# %%
# %cd drive/My Drive/BERT_Base
# !git clone https://github.com/google-research/bert
# Out:
# /content/drive/My Drive/BERT_Base

# %%
# !ls
# Out:
# bert  config.json  IT-vocab.txt  tf_examples.tfrecord

# %%
# bwpt.save('/content/drive/My Drive/BERT_Base/','IT')
# Out:
# ['/content/drive/My Drive/BERT_Base/IT-vocab.txt']

# %%
# !ls
# %cd bert
# !ls
# Out:
# bert  config.json  IT-vocab.txt  tf_examples.tfrecord
# /content/drive/My Drive/BERT_Base/bert
# config.json		    predicting_movie_reviews_with_bert_on_tf_hub.ipynb
# CONTRIBUTING.md		    __pycache__
# create_pretraining_data.py  README.md
# extract_features.py	    requirements.txt
# __init__.py		    run_classifier.py
# LICENSE			    run_classifier_with_tfhub.py
# modeling.py		    run_pretraining.py
# modeling_test.py	    run_squad.py
# multilingual.md		    sample_text.txt
# optimization.py		    tokenization.py
# optimization_test.py	    tokenization_test.py

# %%
# ! tail -50 /content/drive/My\ Drive/BERT_Base/IT-vocab.txt
# Out:
# ##1114
# numberi
# resetpassword
# ##60a
# ##60b
# certutil
# certbot
# 3012
# 30ms
# 042
# ios11
# ##3088
# ##geb
# router1
# drush
# incapable
# javapath
# notificationsi
# inputevent
# item2
# restorei
# successfull
# ##external
# ##5500
# internalcommands
# customised
# invas
# functioned
# privs
# pyo
# ##90m
# autoexec
# dnssd
# ##72a
# coregraphics
# 80ghz
# 023
# repairable
# ##35e
# ##88cfd
# 0000020
# singular
# singleusert
# documenti
# airtel
# sda11
# pepper
# echoed
# 3130
# psize

# %%
# !python create_pretraining_data.py \
#     --input_file= /content/drive/My\ Drive/Data/text_corpus2.txt \
#     --output_file=/content/drive/My\ Drive/BERT_Base/tf_examples.tfrecord \
#     --vocab_file=/content/drive/My\ Drive/BERT_Base/IT-vocab.txt \
#     --do_lower_case=True \
#     --max_seq_length=128 \
#     --max_predictions_per_seq=20 \
#     --masked_lm_prob=0.15 \
#     --random_seed=42 \
#     --dupe_factor=5
# Out:
# WARNING:tensorflow:From create_pretraining_data.py:469: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From create_pretraining_data.py:437: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# W1026 11:45:40.215379 140333626431360 module_wrapper.py:139] From create_pretraining_data.py:437: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From create_pretraining_data.py:437: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# W1026 11:45:40.215943 140333626431360 module_wrapper.py:139] From create_pretraining_data.py:437: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# ...

# %%
# !python run_pretraining.py \
    --input_file=/content/drive/My\ Drive/BERT_Base/tf_examples.tfrecord \
    --output_dir=/content/drive/My\ Drive/BERT_Base/model \
    --do_train=True \
    --do_eval=True \
    --bert_config_file=/content/drive/My\ Drive/BERT_Base/config.json \
    --train_batch_size=32 \
    --max_seq_length=128 \
    --max_predictions_per_seq=20 \
    --num_train_steps=20 \
    --num_warmup_steps=10 \
    --learning_rate=2e-5 \
# Out:
# WARNING:tensorflow:From /content/drive/My Drive/BERT_Base/bert/optimization.py:87: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From run_pretraining.py:493: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From run_pretraining.py:407: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# W1026 16:49:50.914551 140454629173120 module_wrapper.py:139] From run_pretraining.py:407: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From run_pretraining.py:407: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# W1026 16:49:50.914773 140454629173120 module_wrapper.py:139] From run_pretraining.py:407: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# ...

# %% [markdown]
# After running the model from scratch, we get
#
# masked_lm_accuracy = 5%
#
# next_sentence_accuracy = 62.5%
